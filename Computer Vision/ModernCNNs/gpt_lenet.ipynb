# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim

device = 'cuda'
# Define the transformation to resize images to 32x32 and convert them to tensors
transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.ToTensor()
])

# Download and install the Fashion MNIST dataset
train_dataset = torchvision.datasets.FashionMNIST(
    root='./data',
    train=True,
    download=True,
    transform=transform
)

test_dataset = torchvision.datasets.FashionMNIST(
    root='./data',
    train=False,
    download=True,
    transform=transform
)

# Create data loaders for training and testing
train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True
)

test_loader = torch.utils.data.DataLoader(
    test_dataset,
    batch_size=32,
    shuffle=False
)

# Define the LeNet architecture
class LeNet(nn.Module):
    def __init__(self, num_classes=10):
        super(LeNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1, 6, kernel_size=5),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(6, 16, kernel_size=5),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.classifier = nn.Sequential(
            nn.Linear(16 * 5 * 5, 120),
            nn.ReLU(),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Linear(84, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

# Create an instance of the LeNet model
model = LeNet().to(device)

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# Training loop
num_epochs = 5
for epoch in range(num_epochs):
    running_loss = 0.0

    # Training
    model.train()  # Set the model in training mode
    for i, (images, labels) in enumerate(train_loader, 0):
        inputs = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # Print statistics every 100 mini-batches
        if i % 100 == 99:
            print(f'Training: Epoch [{epoch+1}/{num_epochs}], Mini-batch: [{i+1}/{len(train_loader)}], Loss: {running_loss/100:.3f}')
            running_loss = 0.0

    # Validation
    model.eval()  # Set the model in evaluation mode
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            inputs = images.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    validation_accuracy = 100 * correct / total
    print(f'Validation: Epoch [{epoch+1}/{num_epochs}], Accuracy: {validation_accuracy:.2f}%')

print('Training and validation finished.')
# Out:
# Training: Epoch [1/5], Mini-batch: [100/1875], Loss: 2.304
# Training: Epoch [1/5], Mini-batch: [200/1875], Loss: 2.303
# Training: Epoch [1/5], Mini-batch: [300/1875], Loss: 2.301
# Training: Epoch [1/5], Mini-batch: [400/1875], Loss: 2.300
# Training: Epoch [1/5], Mini-batch: [500/1875], Loss: 2.298
# Training: Epoch [1/5], Mini-batch: [600/1875], Loss: 2.296
# Training: Epoch [1/5], Mini-batch: [700/1875], Loss: 2.292
# Training: Epoch [1/5], Mini-batch: [800/1875], Loss: 2.282
# Training: Epoch [1/5], Mini-batch: [900/1875], Loss: 2.257
# Training: Epoch [1/5], Mini-batch: [1000/1875], Loss: 2.174
# Training: Epoch [1/5], Mini-batch: [1100/1875], Loss: 1.730
# Training: Epoch [1/5], Mini-batch: [1200/1875], Loss: 1.227
# Training: Epoch [1/5], Mini-batch: [1300/1875], Loss: 1.120
# Training: Epoch [1/5], Mini-batch: [1400/1875], Loss: 1.043
# Training: Epoch [1/5], Mini-batch: [1500/1875], Loss: 0.979
# Training: Epoch [1/5], Mini-batch: [1600/1875], Loss: 0.936
# Training: Epoch [1/5], Mini-batch: [1700/1875], Loss: 0.887
# Training: Epoch [1/5], Mini-batch: [1800/1875], Loss: 0.902
# Validation: Epoch [1/5], Accuracy: 63.07%
# Training: Epoch [2/5], Mini-batch: [100/1875], Loss: 0.838
# Training: Epoch [2/5], Mini-batch: [200/1875], Loss: 0.799
# Training: Epoch [2/5], Mini-batch: [300/1875], Loss: 0.804
# Training: Epoch [2/5], Mini-batch: [400/1875], Loss: 0.799
# Training: Epoch [2/5], Mini-batch: [500/1875], Loss: 0.791
# Training: Epoch [2/5], Mini-batch: [600/1875], Loss: 0.741
# Training: Epoch [2/5], Mini-batch: [700/1875], Loss: 0.720
# Training: Epoch [2/5], Mini-batch: [800/1875], Loss: 0.733
# Training: Epoch [2/5], Mini-batch: [900/1875], Loss: 0.734
# Training: Epoch [2/5], Mini-batch: [1000/1875], Loss: 0.717
# Training: Epoch [2/5], Mini-batch: [1100/1875], Loss: 0.684
# Training: Epoch [2/5], Mini-batch: [1200/1875], Loss: 0.651
# Training: Epoch [2/5], Mini-batch: [1300/1875], Loss: 0.665
# Training: Epoch [2/5], Mini-batch: [1400/1875], Loss: 0.673
# Training: Epoch [2/5], Mini-batch: [1500/1875], Loss: 0.653
# Training: Epoch [2/5], Mini-batch: [1600/1875], Loss: 0.659
# Training: Epoch [2/5], Mini-batch: [1700/1875], Loss: 0.645
# Training: Epoch [2/5], Mini-batch: [1800/1875], Loss: 0.638
# Validation: Epoch [2/5], Accuracy: 73.38%
# Training: Epoch [3/5], Mini-batch: [100/1875], Loss: 0.638
# Training: Epoch [3/5], Mini-batch: [200/1875], Loss: 0.633
# Training: Epoch [3/5], Mini-batch: [300/1875], Loss: 0.605
# Training: Epoch [3/5], Mini-batch: [400/1875], Loss: 0.593
# Training: Epoch [3/5], Mini-batch: [500/1875], Loss: 0.598
# Training: Epoch [3/5], Mini-batch: [600/1875], Loss: 0.591
# Training: Epoch [3/5], Mini-batch: [700/1875], Loss: 0.585
# Training: Epoch [3/5], Mini-batch: [800/1875], Loss: 0.565
# Training: Epoch [3/5], Mini-batch: [900/1875], Loss: 0.573
# Training: Epoch [3/5], Mini-batch: [1000/1875], Loss: 0.575
# Training: Epoch [3/5], Mini-batch: [1100/1875], Loss: 0.552
# Training: Epoch [3/5], Mini-batch: [1200/1875], Loss: 0.564
# Training: Epoch [3/5], Mini-batch: [1300/1875], Loss: 0.556
# Training: Epoch [3/5], Mini-batch: [1400/1875], Loss: 0.534
# Training: Epoch [3/5], Mini-batch: [1500/1875], Loss: 0.560
# Training: Epoch [3/5], Mini-batch: [1600/1875], Loss: 0.517
# Training: Epoch [3/5], Mini-batch: [1700/1875], Loss: 0.535
# Training: Epoch [3/5], Mini-batch: [1800/1875], Loss: 0.534
# Validation: Epoch [3/5], Accuracy: 78.10%
# Training: Epoch [4/5], Mini-batch: [100/1875], Loss: 0.527
# Training: Epoch [4/5], Mini-batch: [200/1875], Loss: 0.507
# Training: Epoch [4/5], Mini-batch: [300/1875], Loss: 0.527
# Training: Epoch [4/5], Mini-batch: [400/1875], Loss: 0.514
# Training: Epoch [4/5], Mini-batch: [500/1875], Loss: 0.505
# Training: Epoch [4/5], Mini-batch: [600/1875], Loss: 0.488
# Training: Epoch [4/5], Mini-batch: [700/1875], Loss: 0.523
# Training: Epoch [4/5], Mini-batch: [800/1875], Loss: 0.540
# Training: Epoch [4/5], Mini-batch: [900/1875], Loss: 0.526
# Training: Epoch [4/5], Mini-batch: [1000/1875], Loss: 0.490
# Training: Epoch [4/5], Mini-batch: [1100/1875], Loss: 0.517
# Training: Epoch [4/5], Mini-batch: [1200/1875], Loss: 0.486
# Training: Epoch [4/5], Mini-batch: [1300/1875], Loss: 0.496
# Training: Epoch [4/5], Mini-batch: [1400/1875], Loss: 0.491
# Training: Epoch [4/5], Mini-batch: [1500/1875], Loss: 0.489
# Training: Epoch [4/5], Mini-batch: [1600/1875], Loss: 0.485
# Training: Epoch [4/5], Mini-batch: [1700/1875], Loss: 0.498
# Training: Epoch [4/5], Mini-batch: [1800/1875], Loss: 0.487
# Validation: Epoch [4/5], Accuracy: 79.99%
# Training: Epoch [5/5], Mini-batch: [100/1875], Loss: 0.482
# Training: Epoch [5/5], Mini-batch: [200/1875], Loss: 0.475
# Training: Epoch [5/5], Mini-batch: [300/1875], Loss: 0.466
# Training: Epoch [5/5], Mini-batch: [400/1875], Loss: 0.446
# Training: Epoch [5/5], Mini-batch: [500/1875], Loss: 0.482
# Training: Epoch [5/5], Mini-batch: [600/1875], Loss: 0.457
# Training: Epoch [5/5], Mini-batch: [700/1875], Loss: 0.465
# Training: Epoch [5/5], Mini-batch: [800/1875], Loss: 0.472
# Training: Epoch [5/5], Mini-batch: [900/1875], Loss: 0.474
# Training: Epoch [5/5], Mini-batch: [1000/1875], Loss: 0.462
# Training: Epoch [5/5], Mini-batch: [1100/1875], Loss: 0.469
# Training: Epoch [5/5], Mini-batch: [1200/1875], Loss: 0.455
# Training: Epoch [5/5], Mini-batch: [1300/1875], Loss: 0.476
# Training: Epoch [5/5], Mini-batch: [1400/1875], Loss: 0.465
# Training: Epoch [5/5], Mini-batch: [1500/1875], Loss: 0.458
# Training: Epoch [5/5], Mini-batch: [1600/1875], Loss: 0.452
# Training: Epoch [5/5], Mini-batch: [1700/1875], Loss: 0.428
# Training: Epoch [5/5], Mini-batch: [1800/1875], Loss: 0.459
# Validation: Epoch [5/5], Accuracy: 83.02%
# Training and validation finished.
